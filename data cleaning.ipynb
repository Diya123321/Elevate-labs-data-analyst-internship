# %%
import numpy as np
import pandas as pd

# %% [markdown]
# TAKING NETFLIX SHOWS AND MOVIES DATASET

# %%
data = pd.read_csv('netflix_titles.csv')

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.info()
data.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.columns=data.columns.str.strip().str.lower().str.lower().str.replace(' ','_')

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data['director']=data['director'].fillna('Unknown')

# %%
data['release_year']=data['release_year'].astype(int)

# %%
data=data.dropna(subset=['date_added'])

# %%
data.reset_index(drop=True,inplace=True)

# %%
data['cast']=data['cast'].fillna('Unknown')

# %%
data['country']=data['country'].fillna('Unknown')

# %%
data.drop(columns=['rating'],inplace=True)

# %%
data.head(100)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# ..     ...      ...                                                ...
# 95     s96  TV Show                                         The Circle
# 96     s97    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 97     s98  TV Show                                         Kid Cosmic
# 98     s99  TV Show                          Octonauts: Above & Beyond
# 99    s100  TV Show                                       On the Verge
#
#            director                                               cast  \
# ...

# %%
data=data[data['date_added'].str.lower() !='unkonwn']

# %%
data.head(300)
# Out:
#     show_id     type                  title  \
# 0        s1    Movie   Dick Johnson Is Dead
# 1        s2  TV Show          Blood & Water
# 2        s3  TV Show              Ganglands
# 3        s4  TV Show  Jailbirds New Orleans
# 4        s5  TV Show           Kota Factory
# ..      ...      ...                    ...
# 295    s296    Movie       The Paper Tigers
# 296    s297  TV Show              Hit & Run
# 297    s298  TV Show               Navarasa
# 298    s299    Movie           Quam's Money
# 299    s300    Movie              The Swarm
#
#                                               director  \
# 0                                      Kirsten Johnson
# 1                                              Unknown
# 2                                      Julien Leclercq
# 3                                              Unknown
# 4                                              Unknown
# ..                                                 ...
# ...

# %%
data['duration']=data['duration'].fillna('0 min')

# %%
data=data.drop(columns=['director'])

# %%
data_raw=pd.read_csv('netflix_titles.csv')

# %%
len(data)
# Out:
# 8797

# %%
len(data_raw)
# Out:
# 8807

# %%
data=data.merge(data_raw[['show_id','director']],on ='show_id',how='left')

# %%
data.head()
# Out:
#   show_id     type                  title  \
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year   duration  \
# 0  September 25, 2021          2020     90 min
# 1  September 24, 2021          2021  2 Seasons
# 2  September 24, 2021          2021   1 Season
# 3  September 24, 2021          2021   1 Season
# 4  September 24, 2021          2021  2 Seasons
#
# ...

# %%
data['director']=data['director'].fillna("Unknown")

# %%
data.head()
# Out:
#   show_id     type                  title  \
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year   duration  \
# 0  September 25, 2021          2020     90 min
# 1  September 24, 2021          2021  2 Seasons
# 2  September 24, 2021          2021   1 Season
# 3  September 24, 2021          2021   1 Season
# 4  September 24, 2021          2021  2 Seasons
#
# ...

# %%
print(data.isnull().sum())
# Out:
# show_id         0
# type            0
# title           0
# cast            0
# country         0
# date_added      0
# release_year    0
# duration        0
# listed_in       0
# description     0
# director        0
# dtype: int64

# %%
data=data[~data.apply(lambda row:row.astype(str).str.lower().str.contains('Unknown').any(),axis=1)]

# %%
data.head(50)

# %%
len(data)

# %%
Unknown_dates=data[data['date_added'].str.lower() =='unknown']

# %%
print(Unknown_dates)

# %%
data=data.drop([6066,6174,6795,6806,6901,7196,7254,7406,7847,8182])

# %%
data.head()

# %%
len(data)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.to_csv('netflix_cleaned.csv',index=False)
